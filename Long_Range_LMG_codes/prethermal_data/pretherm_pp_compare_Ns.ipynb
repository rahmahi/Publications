# %%
import hdfdict
import h5py
import numpy as np
import matplotlib.pyplot as plt

fname = 'frz_multomega_20230427_0938_o1.h5'
f = h5py.File(fname, 'r')
fulldata = hdfdict.load(fname)
h0 = f.attrs['h0']
N = f.attrs['N'] 
nperiods = f.attrs['nperiods']
f.close()
print(h0,N, nperiods)
# Out:
# 1.5707963267948966 50 12000

# %%
fname = 'frz_multomega_20230427_0938_o3.h5'
f = h5py.File(fname, 'r')
fulldata1 = hdfdict.load(fname)
h0 = f.attrs['h0']
N = f.attrs['N'] 
nperiods = f.attrs['nperiods']
f.close()
print(h0,N, nperiods)
# Out:
# 1.5707963267948966 50 12000

# %%
fname = 'frz_multomega_20230427_0938_o2.h5'
f = h5py.File(fname, 'r')
fulldata2 = hdfdict.load(fname)
h0 = f.attrs['h0']
N = f.attrs['N'] 
nperiods = f.attrs['nperiods']
f.close()
print(h0,N, nperiods)
# Out:
# 1.5707963267948966 50 12000

# %%
fname = fname = 'frz_multomega_20230427_0938_o56.h5'
f = h5py.File(fname, 'r')
fulldata3 = hdfdict.load(fname)
h0 = f.attrs['h0']
N = f.attrs['N'] 
nperiods = f.attrs['nperiods']
f.close()
print(h0,N, nperiods)
# Out:
# 1.5707963267948966 50 12000

# %%
fname = 'frz_multomega_20230427_0938_o4.h5'
f = h5py.File(fname, 'r')
fulldata4 = hdfdict.load(fname)
h0 = f.attrs['h0']
N = f.attrs['N'] 
nperiods = f.attrs['nperiods']
f.close()
print(h0,N, nperiods)
# Out:
# 1.5707963267948966 50 12000

# %% [markdown]
# AR's data for N =100

# %%
fname = 'frz_multomega_20230329_1345_N100.h5'
f = h5py.File(fname, 'r')
fulldata5 = hdfdict.load(fname)
h0 = f.attrs['h0']
N = f.attrs['N'] 
nperiods = f.attrs['nperiods']
f.close()
print(h0,N, nperiods)
# Out:
# 1.5707963267948966 100 12000

# %%
fname = 'frz_multomega_20230406_0920_N100.h5'
f = h5py.File(fname, 'r')
fulldata6 = hdfdict.load(fname)
h0 = f.attrs['h0']
N = f.attrs['N'] 
nperiods = f.attrs['nperiods']
f.close()
print(h0,N, nperiods)
# Out:
# 1.5707963267948966 100 12000

# %%
fname = 'frz_multomega_20230406_1117_N100.h5'
f = h5py.File(fname, 'r')
fulldata7 = hdfdict.load(fname)
h0 = f.attrs['h0']
N = f.attrs['N'] 
nperiods = f.attrs['nperiods']
f.close()
print(h0,N, nperiods)
# Out:
# 1.5707963267948966 100 12000

# %%
omegas5 = np.array([value['metadata']['omega'] for key, value in fulldata5.items()])
omegas6 = np.array([value['metadata']['omega'] for key, value in fulldata6.items()])
omegas7 = np.array([value['metadata']['omega'] for key, value in fulldata7.items()])

# %%
# !ls *.h5
# Out:
# frz_multomega_20230329_1345_N100.h5  frz_multomega_20230427_0938_o2.h5
# frz_multomega_20230406_0920_N100.h5  frz_multomega_20230427_0938_o3.h5
# frz_multomega_20230406_1117_N100.h5  frz_multomega_20230427_0938_o4.h5
# frz_multomega_20230425_1415.h5	     frz_multomega_20230427_0938_o56.h5
# frz_multomega_20230426.h5	     nfrz_multomega_20230412_1120_N100.h5
# frz_multomega_20230427_0938_o1.h5

# %%
omegas = np.array([value['metadata']['omega'] for key, value in fulldata.items()])
omegas1 = np.array([value['metadata']['omega'] for key, value in fulldata1.items()])
omegas2 = np.array([value['metadata']['omega'] for key, value in fulldata2.items()])
omegas3 = np.array([value['metadata']['omega'] for key, value in fulldata3.items()])
omegas4 = np.array([value['metadata']['omega'] for key, value in fulldata4.items()])

print(omegas, omegas2, omegas3)
# Out:
# [1.         1.08163265 1.81632653 1.89795918 1.97959184 2.06122449
#  2.14285714 2.2244898  2.30612245 2.3877551  2.46938776 2.55102041
#  1.16326531 2.63265306 2.71428571 2.79591837 2.87755102 2.95918367
#  3.04081633 3.12244898 3.20408163 3.28571429 3.36734694 1.24489796
#  3.44897959 3.53061224 3.6122449  3.69387755 3.7755102  3.85714286
#  3.93877551 4.02040816 4.10204082 4.18367347 1.32653061 4.26530612
#  4.34693878 4.42857143 4.51020408 4.59183673 4.67346939 4.75510204
#  4.83673469 4.91836735 5.         1.40816327 1.48979592 1.57142857
#  1.65306122 1.73469388] [ 5.1         5.16202532  5.72025316  5.78227848  5.8443038   5.90632911
#   5.96835443  6.03037975  6.09240506  6.15443038  6.2164557   6.27848101
#   5.22405063  6.34050633  6.40253165  6.46455696  6.52658228  6.58860759
#   6.65063291  6.71265823  6.77468354  6.83670886  6.89873418  5.28607595
#   6.96075949  7.02278481  7.08481013  7.14683544  7.20886076  7.27088608
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams.update({"figure.figsize": (15, 9),"text.usetex": True,"font.family": "sans-serif",
    "font.size": 15,"font.sans-serif": ["Helvetica"], "axes.edgecolor": "black", "axes.linewidth": 1.0})

allkeys = [str(i) for i in np.arange(len(omegas))]
allkeys1 = [str(i) for i in np.arange(len(omegas1))]
allkeys2 = [str(i) for i in np.arange(len(omegas2))]
allkeys3 = [str(i) for i in np.arange(len(omegas3))]
allkeys4 = [str(i) for i in np.arange(len(omegas4))]

allkeys5 = [str(i) for i in np.arange(len(omegas5))]
allkeys6 = [str(i) for i in np.arange(len(omegas6))]
allkeys7 = [str(i) for i in np.arange(len(omegas7))]

#allkeys = [str(i) for i in np.arange(30)]
#allkeys2 = [str(i) for i in np.arange(30)]
#allkeys3 = [str(i) for i in np.arange(19)]

allomegas, allomegas1 = [], []
ebar, ebar1 = [], []
evbar, evbar1 = [], []
for key in allkeys:
    data = fulldata[key]
    omega = data['metadata']['omega']
    allomegas.append(omega)
    h = data['metadata']['h']
    ebar.append(np.average(data['eavg']).real)
    evbar.append(np.average(data['evar']).real)
    
for key in allkeys1:
    data = fulldata[key]
    omega = data['metadata']['omega']
    allomegas.append(omega)
    h = data['metadata']['h']
    ebar.append(np.average(data['eavg']).real)
    evbar.append(np.average(data['evar']).real)

for key in allkeys2:
    data = fulldata2[key]
    omega = data['metadata']['omega']
    allomegas.append(omega)
    h = data['metadata']['h']
    ebar.append(np.average(data['eavg']).real)
    evbar.append(np.average(data['evar']).real)
    
for key in allkeys3:
    data = fulldata3[key]
    omega = data['metadata']['omega']
    allomegas.append(omega)
    h = data['metadata']['h']
    ebar.append(np.average(data['eavg']).real)
    evbar.append(np.average(data['evar']).real)
    
for key in allkeys4:
    data = fulldata4[key]
    omega = data['metadata']['omega']
    allomegas.append(omega)
    h = data['metadata']['h']
    ebar.append(np.average(data['eavg']).real)
    evbar.append(np.average(data['evar']).real)
    
#--------------------------------------------------
for key in allkeys5:
    data = fulldata5[key]
    omega = data['metadata']['omega']
    allomegas1.append(omega)
    h = data['metadata']['h']
    ebar1.append(np.average(data['eavg']).real)
    evbar.append(np.average(data['evar']).real)
    
for key in allkeys6:
    data = fulldata6[key]
    omega = data['metadata']['omega']
    allomegas1.append(omega)
    h = data['metadata']['h']
    ebar1.append(np.average(data['eavg']).real)
    evbar.append(np.average(data['evar']).real)
    
for key in allkeys7:
    data = fulldata7[key]
    omega = data['metadata']['omega']
    allomegas1.append(omega)
    h = data['metadata']['h']
    ebar1.append(np.average(data['eavg']).real)
    evbar.append(np.average(data['evar']).real)
#--------------------------------------------------
    
x, y = zip(*sorted(zip(allomegas,ebar)))
x1, y1 = zip(*sorted(zip(allomegas1,ebar1)))

plt.plot(x,y,marker='o', label='N=50')
plt.plot(x1,y1,marker='v', label='N=100', linestyle='--')

#plt.xlim((0.0,5.0))
plt.xlabel(fr'$\omega$')
plt.ylabel(fr'$\langle\langle H(t)\rangle\rangle$')
#plt.title(fr'$N={N}$')
plt.xlim(0,15)
figname = 'avg_plot_N='+ str(N)+'_.jpeg'
plt.legend()
plt.savefig(figname, dpi= 500)
plt.show()

# %% [markdown]
# Cumulative average

# %%
keys = ['5','10', '15']
for key in keys:
    data = fulldata4[key]
    omega = data['metadata']['omega']
    h = data['metadata']['h']
    print('w=', omega, 'h=', h)
    ht_s = data['eavg']
    ht_cs = np.cumsum(ht_s)/(1+ np.arange(len(ht_s)))
    omg = 'w=' +str(omega)
    plt.plot(ht_cs, label = omg)
plt.legend()
plt.xlabel('n')
plt.xlim(0,200)
plt.show()
# Out:
# w= 0.31052631578947365 h= 0.5446310704198967
# w= 0.5210526315789473 h= 0.9138724740944029
# w= 0.731578947368421 h= 1.283113877768909
# /home/mahi/anaconda3/envs/work3p8/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:1335: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
keys = ['5','12', '20']
for key in keys:
    data = fulldata[key]
    omega = data['metadata']['omega']
    h = data['metadata']['h']
    print('w=', omega, 'h=', h)
    ht_s = data['eavg']
    ht_cs = np.cumsum(ht_s)/(1+ np.arange(len(ht_s)))
    omg = 'w=' +str(omega)
    plt.plot(ht_cs, label = omg)
plt.legend()
#plt.xlim(0,200)
plt.xlabel("n")
plt.show()
# Out:
# w= 1.4081632653061225 h= 2.469772858251417
# w= 1.9795918367346939 h= 3.471999525367934
# w= 2.63265306122449 h= 4.6174014306439535

# %%
keys = ['10']
for key in keys:
    data = fulldata4[key]
    omega = data['metadata']['omega']
    h = data['metadata']['h']
    print('w=', omega, 'h=', h)
    ht_s = data['eavg']
    ht_cs = np.cumsum(ht_s)/(1+ np.arange(len(ht_s)))
    omg = 'w=' +str(omega)
    plt.plot(ht_cs, label = omg, linestyle ='--')


keys = ['12']
for key in keys:
    data = fulldata[key]
    omega = data['metadata']['omega']
    h = data['metadata']['h']
    print('w=', omega, 'h=', h)
    ht_s = data['eavg']
    ht_cs = np.cumsum(ht_s)/(1+ np.arange(len(ht_s)))
    omg = 'w=' +str(omega)
    plt.plot(ht_cs, label = omg)
plt.legend()
plt.xlim(-10,75)
plt.ylim(-4,.2)
plt.xlabel("n")
plt.savefig('cumsumavg.jpeg', dpi= 500)
plt.show()
# Out:
# w= 0.5210526315789473 h= 0.9138724740944029
# w= 1.9795918367346939 h= 3.471999525367934
# /home/mahi/anaconda3/envs/work3p8/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:1335: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %% [markdown]
# # Long time exact evolution

# %%
from qutip import mesolve, basis, jmat, Options, expect
from multiprocessing import Pool
from tqdm import tqdm
from scipy.special import jn_zeros
import numpy as np
import matplotlib.pyplot as plt

def drive(t, args):
    w = args['omega']
    h = args['h']
    h0 = args['h0']
    return h * np.sin(w*t) + h0

def get_hamiltonians(N):
    sx,sy,sz = jmat(N,"x"),jmat(N,"y"),jmat(N,"z")
    kn =  2.0/(N-1)                                     
    H0 = kn * sz **2 
    H1 = 2 * sx
    return H0,H1

def sys_evolve(w,N,opts):
    sx,sy,sz = jmat(N,"x"),jmat(N,"y"),jmat(N,"z")
    T = 2 * np.pi/w
    h = jn_zeros(0,5)[0]* w / 4.0
    params = {'h0':np.pi/32, 'h':h,'omega':w, 'N':N} 
    H0, H1 = get_hamiltonians(N)
    H = [H0,[H1,drive]]
    en, sts = Sx.eigenstates() 
    rho0 = sts[0]
    #times = np.linspace(0,75*T, 75+1)
    times = np.linspace(0,75*T, 4000)
    hbar = []
    out = mesolve(H, rho0, times, [], [], args = params, options=opts)
    psi_ts = out.states
    
    for i,t in enumerate(times):
        psit = np.array(psi_ts[i].full())[:,0].reshape(2*N+1,1)
        Ht = H0 + H1 * drive(t, params)
        Ht = np.array(Ht.full())
        hbar.append(np.conjugate(psit).T @ Ht @ psit)
    hbar = (np.array(hbar)/N).reshape(len(times),1)
    return hbar.real, (times/(2*np.pi/w)).reshape(len(times),1)

if __name__ == '__main__':
    nprocs = 2
    N = 50
    omegas = [0.5210526315789473,1.9795918367346939]
    p = Pool(processes = nprocs)
    print("running for TSS spin N=",N, 'nprocs=',nprocs," !")
    opts = Options(nsteps=1e6, num_cpus=nprocs, openmp_threads=1, atol=1e-12, rtol=1e-14)
    data = np.array(p.starmap(sys_evolve,tqdm([(w,N, opts) for w in omegas])))
# Out:
# running for TSS spin N= 50 nprocs= 2  !
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 1953.56it/s]

# %%
for i,w in enumerate(omegas):
    hbar = data[i][0][:,0]
    times = data[i][1][:,0]
    
    hcum = np.cumsum(hbar)/(1+ np.arange(len(hbar)))
    if i ==0:
        plt.plot(times, hcum, label=fr'$\omega={w:1.3f}$', linestyle ='--')
    else:
        plt.plot(times, hbar, label=fr'$\omega={w:1.3f}$')
    
plt.legend()
plt.xlabel('time period (n)')
plt.ylabel(r"$\langle H(t) \rangle$")
plt.savefig('exactcumsumavg.jpeg', dpi= 400)
plt.show()

# %%
for i,w in enumerate(omegas):
    hbar = data[i][0][:,0]
    times = data[i][1][:,0]
    
    hcum = np.cumsum(hbar)/(1+ np.arange(len(hbar)))
    plt.plot(times, hcum, label=fr'$\omega={w:1.3f}$')
    #plt.plot(times, hbar, label=fr'$\omega={w:1.3f}$')
    
plt.legend()
plt.xlabel('time period (n)')
plt.ylabel(r"$\langle H(t) \rangle$")
#plt.xlim(-5,10)
plt.show()

# %% [markdown]
# # Long time average of <H(t)>

# %%
from qutip import mesolve, basis, jmat, Options, expect, Qobj
from multiprocessing import Pool
from tqdm import tqdm
from scipy.special import jn_zeros
import numpy as np
import matplotlib.pyplot as plt

def drive(t, args):
    w = args['omega']
    h = args['h']
    h0 = args['h0']
    return h * np.sin(w*t) + h0

def get_hamiltonians(N):
    sx,sy,sz = jmat(N,"x"),jmat(N,"y"),jmat(N,"z")
    kn =  2.0/(N-1)                                     
    H0 = kn * sz **2 
    H1 = 2 * sx
    return H0,H1

def sys_evolve(w,N,opts):
    sx,sy,sz = jmat(N,"x"),jmat(N,"y"),jmat(N,"z")
    T = 2 * np.pi/w
    h = jn_zeros(0,5)[0]* w / 4.0
    params = {'h0':np.pi/32, 'h':h,'omega':w, 'N':N} 
    H0, H1 = get_hamiltonians(N)
    H = [H0,[H1,drive]]
    en, sts = sx.eigenstates() 
    rho0 = sts[0]
    times = np.linspace(0,75*T, 4000)
    hbar = []
    out = mesolve(H, rho0, times, [], [], args = params, options=opts)
    psi_ts = out.states
    
    for i,t in enumerate(times):
        Ht = H0 + H1 * drive(t, params)
        hbar.append(expect(Qobj(Ht),psi_ts[i]))
    hbar = (np.array(hbar)/N).reshape(len(times),1)
    return hbar.real, (times/(2*np.pi/w)).reshape(len(times),1)

if __name__ == '__main__':
    nprocs = 13
    N = 50
    #o1 = np.linspace(1.29, 1.58, 5)
    #o2 = np.linspace(1.6, 2.5, 5)
    o3 = np.linspace(2.8, 4.38, 5)
    o4 = np.linspace(8, 9.4, 5)
    o5 = np.linspace(9.5, 20.0, 5)
    o6 = np.linspace(20.1, 50.0, 5)


    #omega_vals = np.concatenate((o1, o2, o3, o4, o5))
    omega_vals = np.concatenate((o3, o4, o5, o6))
    p = Pool(processes = nprocs)
    print("running for TSS spin N=",N, 'nprocs=',nprocs," !")
    opts = Options(nsteps=1e6, num_cpus=nprocs, openmp_threads=1, atol=1e-12, rtol=1e-14)
    data = np.array(p.starmap(sys_evolve,tqdm([(w,N, opts) for w in omega_vals])))
# Out:
# running for TSS spin N= 2 nprocs= 10  !
# 100%|█████████████████████████████████████████████████████████████| 20/20 [00:00<00:00, 8781.12it/s]

# %%
hbaravg =[]
for i,w in enumerate(omega_vals):
    hbar = data[i][0][:,0]
    times = data[i][1][:,0]
    
    hbaravg.append(np.average(hbar))
plt.plot(omega_vals,hbaravg, label=fr'$\omega={w:1.3f}$')
    
plt.legend()
plt.xlabel(r'$\omega$')
plt.ylabel(r"$\langle H(t) \rangle$")
#plt.xlim(-5,10)
plt.show()
